# %% [markdown]
# # What this is all about
#
# Often laypeople search a single word in the Bible to see where else it occurs. This can be helpful at times, especially with rare words. But far more often the better search is one that involves multiple words.
#
# On <https://parabible.com>, every word has a phrase, clause, and sentence id. This allows searches to be performed with varying levels of specificity so that, for example, words that are likely being used together may be found (I find this particularly useful in Hebrew searches for verb+preposition). This also means that parabible is not dependent on "<within 5 words>" kinds of searches because it has syntax trees that it is leaning against for meaningful associations between words.
#
# The missing piece on Parabible is, however, equivalent phrase/clause/sentence ids for the NT. This has been a source of frustration to me for some time because multiple openly licensed treebanks exist for the NT, they are just far more complicated than the syntax trees provided by the ETCBC for Hebrew data. So I'm trying to wrangle one such tree into something usable in Parabible's database.
#
# Feedback is welcome!

# %%
from lxml import etree
tree = etree.parse('../greek-new-testament/syntax-trees/nestle1904-lowfat/xml/gnt.xml')
# honour xinclude statements:
tree.xinclude()
root = tree.getroot()

# %% [markdown]
# #  Where the Magic Happens
#
# If this cell doesn't make sense, don't worry about it. I think the key is that you take a look at the sample data printed out in the following cell. It is important how the ids are generated but hopefully even if it doesn't make sense for now, the purpose will become clear as you see the examples below.
#
# Okay, this jupyter cell is where we're going to start assigning `clause-node-ids` to words. The trick is, every time we encounter a new `clause` class, we're going to give all the children of that node a unique `clause-node-id`. The deepest clause node's id overrides the shallower ones.
#
# To assign `phrase-node-ids` is slightly more complicated. We want the shallowest possible phrases to be phrase nodes (because otherwise there are loads of phrases with very few words). So we allow a `phrase-node-id` to be passed in. When we discover a clause, however, we assign a new phrase node to the clause's children. If the clause only has `<w>` elements as children, there's only one phrase but if it has any `<wg>` children, each child receives its own `phrase-node-id`.
#
# It is likely that I have made logical errors here because this was pretty experimental for most of the afternoon.

# %%
limit_counter = 0
sentence_id = -1
max_clause = -1

def explore_word_group(wg, c, phrase_id):
    global max_clause, sentence_id
    to_return = []
    for node in wg:
        current_node_is_clause = False
        if node.tag == "pc": continue
            
        clause_id = c
        if node.get("class") == "cl":
            max_clause += 1
            clause_id = max_clause
            current_node_is_clause = True
        
        if node.tag == "wg":
            if current_node_is_clause:
                new_phrase_id = clause_id * 1000
                if len(node.xpath("(wg)")) > 0:
                    for phrase in node:
                        to_return.extend(explore_word_group(phrase, clause_id, new_phrase_id))
                        new_phrase_id += 1
                else:
                    to_return.extend(explore_word_group(node, clause_id, new_phrase_id))
            else:
                to_return.extend(explore_word_group(node, clause_id, phrase_id))
        else:
            to_return.append({
                "wid": node.get("osisId"),
                "sentence_node": sentence_id,
                "clause_node": clause_id,
                "phrase_node": phrase_id,
                "case": node.get("case"), # We'll do a search based on case to experiment
                "lemma": node.get("lemma"),
                "text": node.text
            })
    return to_return

gnt = []
for node in root:
    if node.tag != "book":
        continue
    print(node.get("name"))
    for sentence in node:
        sentence_id += 1
        for child in sentence:
            if child.tag == "wg":
                c = explore_word_group(child, max_clause, 0)
                for w in c:
                    gnt.append(w)
# Out:
# Matthew
# Mark
# Luke
# John
# Acts
# Romans
# 1 Corinthians
# 2 Corinthians
# Galatians
# Ephesians
# Philippians
# Colossians
# 1 Thessalonians
# 2 Thessalonians
# 1 Timothy
# 2 Timothy
# Titus
# Philemon
# Hebrews
# James
# 1 Peter
# 2 Peter
# 1 John
# 2 John
# 3 John
# Jude
# Revelation

# %%
# Here's what some of the data looks like:
for w in gnt[9995:10020]:
    print(w)
# Out:
# {'wid': 'Matt.21.13!13', 'sentence_node': 761, 'clause_node': 2330, 'phrase_node': 2330003, 'case': 'accusative', 'lemma': 'αὐτός', 'text': 'αὐτὸν'}
# {'wid': 'Matt.21.13!14', 'sentence_node': 761, 'clause_node': 2330, 'phrase_node': 2330003, 'case': None, 'lemma': 'ποιέω', 'text': 'ποιεῖτε'}
# {'wid': 'Matt.21.13!15', 'sentence_node': 761, 'clause_node': 2330, 'phrase_node': 2330003, 'case': 'accusative', 'lemma': 'σπήλαιον', 'text': 'σπήλαιον'}
# {'wid': 'Matt.21.13!16', 'sentence_node': 761, 'clause_node': 2330, 'phrase_node': 2330003, 'case': 'genitive', 'lemma': 'λῃστής', 'text': 'λῃστῶν'}
# {'wid': 'Matt.21.14!4', 'sentence_node': 762, 'clause_node': 2332, 'phrase_node': 2332002, 'case': 'nominative', 'lemma': 'τυφλός', 'text': 'τυφλοὶ'}
# {'wid': 'Matt.21.14!5', 'sentence_node': 762, 'clause_node': 2332, 'phrase_node': 2332002, 'case': None, 'lemma': 'καί', 'text': 'καὶ'}
# {'wid': 'Matt.21.14!6', 'sentence_node': 762, 'clause_node': 2332, 'phrase_node': 2332002, 'case': 'nominative', 'lemma': 'χωλός', 'text': 'χωλοὶ'}
# {'wid': 'Matt.21.14!7', 'sentence_node': 762, 'clause_node': 2332, 'phrase_node': 2332003, 'case': None, 'lemma': 'ἐν', 'text': 'ἐν'}
# {'wid': 'Matt.21.14!8', 'sentence_node': 762, 'clause_node': 2332, 'phrase_node': 2332003, 'case': 'dative', 'lemma': 'ὁ', 'text': 'τῷ'}
# {'wid': 'Matt.21.14!9', 'sentence_node': 762, 'clause_node': 2332, 'phrase_node': 2332003, 'case': 'dative', 'lemma': 'ἱερός', 'text': 'ἱερῷ'}
# {'wid': 'Matt.21.14!10', 'sentence_node': 762, 'clause_node': 2331, 'phrase_node': 2331001, 'case': None, 'lemma': 'καί', 'text': 'καὶ'}
# {'wid': 'Matt.21.14!11', 'sentence_node': 762, 'clause_node': 2333, 'phrase_node': 2333000, 'case': None, 'lemma': 'θεραπεύω', 'text': 'ἐθεράπευσεν'}
# {'wid': 'Matt.21.14!12', 'sentence_node': 762, 'clause_node': 2333, 'phrase_node': 2333000, 'case': 'accusative', 'lemma': 'αὐτός', 'text': 'αὐτούς'}
# {'wid': 'Matt.21.15!3', 'sentence_node': 763, 'clause_node': 2335, 'phrase_node': 2335000, 'case': 'nominative', 'lemma': 'ὁ', 'text': 'οἱ'}
# {'wid': 'Matt.21.15!4', 'sentence_node': 763, 'clause_node': 2335, 'phrase_node': 2335000, 'case': 'nominative', 'lemma': 'ἀρχιερεύς', 'text': 'ἀρχιερεῖς'}
# {'wid': 'Matt.21.15!5', 'sentence_node': 763, 'clause_node': 2335, 'phrase_node': 2335000, 'case': None, 'lemma': 'καί', 'text': 'καὶ'}
# {'wid': 'Matt.21.15!6', 'sentence_node': 763, 'clause_node': 2335, 'phrase_node': 2335000, 'case': 'nominative', 'lemma': 'ὁ', 'text': 'οἱ'}
# {'wid': 'Matt.21.15!7', 'sentence_node': 763, 'clause_node': 2335, 'phrase_node': 2335000, 'case': 'nominative', 'lemma': 'γραμματεύς', 'text': 'γραμματεῖς'}
# {'wid': 'Matt.21.15!1', 'sentence_node': 763, 'clause_node': 2335, 'phrase_node': 2335001, 'case': 'nominative', 'lemma': 'ὁράω', 'text': 'ἰδόντες'}
# {'wid': 'Matt.21.15!8', 'sentence_node': 763, 'clause_node': 2335, 'phrase_node': 2335001, 'case': 'accusative', 'lemma': 'ὁ', 'text': 'τὰ'}
# {'wid': 'Matt.21.15!9', 'sentence_node': 763, 'clause_node': 2335, 'phrase_node': 2335001, 'case': 'accusative', 'lemma': 'θαυμάσιος', 'text': 'θαυμάσια'}
# {'wid': 'Matt.21.15!10', 'sentence_node': 763, 'clause_node': 2336, 'phrase_node': 2336000, 'case': 'accusative', 'lemma': 'ὅς', 'text': 'ἃ'}
# {'wid': 'Matt.21.15!11', 'sentence_node': 763, 'clause_node': 2336, 'phrase_node': 2336000, 'case': None, 'lemma': 'ποιέω', 'text': 'ἐποίησεν'}
# {'wid': 'Matt.21.15!12', 'sentence_node': 763, 'clause_node': 2335, 'phrase_node': 2335001, 'case': None, 'lemma': 'καί', 'text': 'καὶ'}
# {'wid': 'Matt.21.15!13', 'sentence_node': 763, 'clause_node': 2335, 'phrase_node': 2335001, 'case': 'accusative', 'lemma': 'ὁ', 'text': 'τοὺς'}

# %%
# Let's create a quick helper function to print out the text of an array of words
def print_ws(ws):
    print(" ".join(map(lambda w: w["text"],ws)))

# %%
# now let's create a dictionary that groups words by their clause_node
words_by_clause_node = {}
for w in gnt:
    c = w["clause_node"]
    if c not in words_by_clause_node:
        words_by_clause_node[c] = []
    words_by_clause_node[c].append(w)

# %%
# To find the first word, we just filter our list of words in the gnt:
first_word = list(filter(lambda w: w["lemma"]=="ὑπακούω", gnt))
print(list(map(lambda w: w["wid"],first_word)))
# Out:
# ['Mark.1.27!22', 'Luke.8.25!27', 'Luke.17.6!23', 'Acts.6.7!21', 'Acts.12.13!10', 'Rom.6.16!13', 'Rom.6.17!10', 'Rom.10.16!4', 'Eph.6.1!3', 'Eph.6.5!3', 'Col.3.20!3', 'Col.3.22!3', 'Heb.5.9!6', 'Heb.11.8!4']

# %%
# Let's try a "followed by" kind of search by hacking the osisId a bit (this doesn't work too well)
def get_next_osisId(o): # o = osisId
    newint = int(o[o.index("!") + 1:]) + 1
    new_o = o[:o.index("!") + 1] + str(newint)
    return new_o
    
for w in first_word:
    o = w["wid"]
    next_wid = get_next_osisId(o)
    next_w = [x for x in gnt if x["wid"] == next_wid]
    to_print = []
    to_print.append(w)
    to_print.extend(next_w)
    print_ws(to_print)
# Out:
# ὑπακούουσιν αὐτῷ
# ὑπακούουσιν αὐτῷ
# ὑπήκουσεν
# ὑπήκουον τῇ
# ὑπακοῦσαι ὀνόματι
# ὑπακούετε
# ὑπηκούσατε
# ὑπήκουσαν τῷ
# ὑπακούετε τοῖς
# ὑπακούετε τοῖς
# ὑπακούετε τοῖς
# ὑπακούετε κατὰ
# ὑπακούουσιν αὐτῷ
# ὑπήκουσεν

# %%
# Based on the first word, find clauses that have the second word
matching_clauses = []
for w in first_word:
    c = w["clause_node"]
    ws = words_by_clause_node[c]
    matches = list(filter(lambda w: w["lemma"]=="ἐκ", ws))
    if len(matches) > 0:
        matching_clauses.append(c)

print("RESULTS:", len(matching_clauses))
for c in matching_clauses:
    print("Clause Nodes:", c, "(", words_by_clause_node[c][0]["wid"], ")")
    print_ws(words_by_clause_node[c])
# Out:
# RESULTS: 1
# Clause Nodes: 16489 ( Rom.6.17!6 )
# ἦτε δοῦλοι τῆς ἁμαρτίας ὑπηκούσατε ἐκ καρδίας τύπον διδαχῆς ἐδουλώθητε τῇ δικαιοσύνῃ

# %%
first_word = list(filter(lambda w: w["lemma"]=="ἀνάγω", gnt))
matching_clauses = []
for w in first_word:
    c = w["clause_node"]
    ws = words_by_clause_node[c]
    matches = list(filter(lambda w: w["case"]=="dative", ws))
    if len(matches) > 0:
        matching_clauses.append(c)

print("RESULTS:", len(matching_clauses))
for c in matching_clauses:
    print("Clause Node:", c, "(", words_by_clause_node[c][0]["wid"], ")")
    print_ws(words_by_clause_node[c])
# Out:
# RESULTS: 4
# Clause Node: 13545 ( Acts.7.41!2 )
# ἐμοσχοποίησαν ἐν ταῖς ἡμέραις ἐκείναις ἀνήγαγον θυσίαν τῷ εἰδώλῳ
# Clause Node: 14151 ( Acts.12.4!14 )
# μετὰ τὸ πάσχα ἀναγαγεῖν αὐτὸν τῷ λαῷ
# Clause Node: 15823 ( Acts.27.2!13 )
# ἀνήχθημεν ὄντος σὺν ἡμῖν Ἀριστάρχου Μακεδόνος Θεσσαλονικέως
# Clause Node: 16004 ( Acts.28.11!1 )
# Μετὰ τρεῖς μῆνας ἀνήχθημεν ἐν πλοίῳ Ἀλεξανδρινῷ

# %%
# Now let's try a phrase search:
words_by_phrase_node = {}
for w in gnt:
    p = w["phrase_node"]
    if p not in words_by_phrase_node:
        words_by_phrase_node[p] = []
    words_by_phrase_node[p].append(w)

# %%
first_word = list(filter(lambda w: w["lemma"]=="Ἰησοῦς", gnt))
matching_phrases = []
for w in first_word:
    p = w["phrase_node"]
    ws = words_by_phrase_node[p]
    matches = list(filter(lambda w: w["lemma"]=="Χριστός", ws))
    if len(matches) > 0:
        matching_phrases.append(p)

print("RESULTS:", len(matching_phrases))
for p in matching_phrases:
    print("Phrase Node:", p, "(", words_by_phrase_node[p][0]["wid"], ")")
    print_ws(words_by_phrase_node[p])
# Out:
# RESULTS: 232
# Phrase Node: 0 ( Matt.1.1!1 )
# Βίβλος γενέσεως Ἰησοῦ Χριστοῦ υἱοῦ Δαυεὶδ υἱοῦ Ἀβραάμ
# Phrase Node: 36001 ( Matt.1.18!1 )
# Τοῦ Ἰησοῦ Χριστοῦ ἡ γένεσις οὕτως ἦν
# Phrase Node: 1798002 ( Matt.16.21!4 )
# Ἰησοῦς Χριστὸς
# Phrase Node: 3480000 ( Mark.1.1!1 )
# Ἀρχὴ τοῦ εὐαγγελίου Ἰησοῦ Χριστοῦ (Υἱοῦ Θεοῦ)
# Phrase Node: 9672001 ( John.1.17!12 )
# διὰ Ἰησοῦ Χριστοῦ
# Phrase Node: 12171001 ( John.17.3!9 )
# σὲ τὸν μόνον ἀληθινὸν Θεὸν καὶ Ἰησοῦν Χριστόν
# Phrase Node: 12691001 ( John.20.31!7 )
# Ἰησοῦς ἐστιν ὁ Χριστὸς ὁ Υἱὸς τοῦ Θεοῦ
# Phrase Node: 12995002 ( Acts.2.38!7 )
# βαπτισθήτω ἕκαστος ὑμῶν ἐπὶ τῷ ὀνόματι Ἰησοῦ Χριστοῦ εἰς ἄφεσιν τῶν ἁμαρτιῶν ὑμῶν
# Phrase Node: 13033003 ( Acts.3.6!16 )
# ἐν τῷ ὀνόματι Ἰησοῦ Χριστοῦ τοῦ Ναζωραίου περιπάτει
# Phrase Node: 13084001 ( Acts.3.20!12 )
# τὸν Χριστὸν Ἰησοῦν
# Phrase Node: 13123000 ( Acts.4.10!11 )
# ἐν τῷ ὀνόματι Ἰησοῦ Χριστοῦ τοῦ Ναζωραίου
# Phrase Node: 13631002 ( Acts.8.12!6 )
# εὐαγγελιζομένῳ περὶ τῆς βασιλείας τοῦ Θεοῦ καὶ τοῦ ὀνόματος Ἰησοῦ Χριστοῦ
# Phrase Node: 13853003 ( Acts.9.34!7 )
# ἰᾶταί σε Ἰησοῦς Χριστός
# Phrase Node: 14007003 ( Acts.10.36!8 )
# εὐαγγελιζόμενος εἰρήνην διὰ Ἰησοῦ Χριστοῦ
# Phrase Node: 14044001 ( Acts.10.48!4 )
# ἐν τῷ ὀνόματι Ἰησοῦ Χριστοῦ
# Phrase Node: 14096001 ( Acts.11.17!14 )
# ἐπὶ τὸν Κύριον Ἰησοῦν Χριστόν
# Phrase Node: 14547002 ( Acts.15.26!6 )
# ὑπὲρ τοῦ ὀνόματος τοῦ Κυρίου ἡμῶν Ἰησοῦ Χριστοῦ
# Phrase Node: 14648000 ( Acts.16.18!17 )
# ἐν ὀνόματι Ἰησοῦ Χριστοῦ
# Phrase Node: 14732002 ( Acts.17.3!17 )
# ὁ Χριστός ὁ Ἰησοῦς
# Phrase Node: 14847002 ( Acts.18.5!21 )
# εἶναι τὸν Χριστὸν Ἰησοῦν
# Phrase Node: 15622002 ( Acts.24.24!21 )
# περὶ τῆς εἰς Χριστὸν Ἰησοῦν πίστεως
# Phrase Node: 16074001 ( Acts.28.31!8 )
# τὰ περὶ τοῦ Κυρίου Ἰησοῦ Χριστοῦ
# Phrase Node: 16075000 ( Rom.1.1!1 )
# Παῦλος δοῦλος Χριστοῦ Ἰησοῦ κλητὸς ἀπόστολος
# Phrase Node: 16077004 ( Rom.1.3!1 )
# περὶ τοῦ Υἱοῦ αὐτοῦ τοῦ τοῦ Ἰησοῦ Χριστοῦ τοῦ Κυρίου ἡμῶν
# Phrase Node: 16081003 ( Rom.1.6!6 )
# κλητοὶ Ἰησοῦ Χριστοῦ
# Phrase Node: 16083002 ( Rom.1.7!14 )
# ἀπὸ Θεοῦ Πατρὸς ἡμῶν καὶ Κυρίου Ἰησοῦ Χριστοῦ
# Phrase Node: 16084001 ( Rom.1.8!1 )
# Πρῶτον εὐχαριστῶ τῷ Θεῷ μου διὰ Ἰησοῦ Χριστοῦ περὶ πάντων ὑμῶν
# Phrase Node: 16187005 ( Rom.2.16!15 )
# διὰ Χριστοῦ Ἰησοῦ
# Phrase Node: 16283000 ( Rom.3.22!1 )
# δικαιοσύνη Θεοῦ διὰ πίστεως Ἰησοῦ Χριστοῦ
# Phrase Node: 16288002 ( Rom.3.24!1 )
# δικαιούμενοι δωρεὰν τῇ αὐτοῦ χάριτι διὰ τῆς ἀπολυτρώσεως τῆς ἐν Χριστῷ Ἰησοῦ
# Phrase Node:
ἀπόστολος Χριστοῦ Ἰησοῦ διὰ θελήματος Θεοῦ καὶ Σωσθένης ὁ ἀδελφὸς τῇ ἐκκλησίᾳ τοῦ Θεοῦ τῇ κλητοῖς ἁγίοις σὺν πᾶσιν τοῖς
# Phrase Node: 17368001 ( 1Cor.1.2!10 )
# ἐν Χριστῷ Ἰησοῦ
# Phrase Node: 17369001 ( 1Cor.1.2!19 )
# τὸ ὄνομα τοῦ Κυρίου ἡμῶν Ἰησοῦ Χριστοῦ
# Phrase Node: 17370002 ( 1Cor.1.3!5 )
# ἀπὸ Θεοῦ Πατρὸς ἡμῶν καὶ Κυρίου Ἰησοῦ Χριστοῦ
# Phrase Node: 17372002 ( 1Cor.1.4!15 )
# ἐν Χριστῷ Ἰησοῦ
# Phrase Node: 17376001 ( 1Cor.1.7!9 )
# τὴν ἀποκάλυψιν τοῦ Κυρίου ἡμῶν Ἰησοῦ Χριστοῦ
# Phrase Node: 17377006 ( 1Cor.1.8!8 )
# ἐν τῇ ἡμέρᾳ τοῦ Κυρίου ἡμῶν Ἰησοῦ Χριστοῦ
# Phrase Node: 17379002 ( 1Cor.1.9!7 )
# εἰς κοινωνίαν τοῦ Υἱοῦ αὐτοῦ Ἰησοῦ Χριστοῦ τοῦ Κυρίου ἡμῶν
# Phrase Node: 17380002 ( 1Cor.1.10!1 )
# Παρακαλῶ ὑμᾶς διὰ τοῦ ὀνόματος τοῦ Κυρίου ἡμῶν Ἰησοῦ Χριστοῦ
# Phrase Node: 17439001 ( 1Cor.1.30!1 )
# ἐξ αὐτοῦ ὑμεῖς ἐστε ἐν Χριστῷ Ἰησοῦ
# Phrase Node: 17448001 ( 1Cor.2.2!10 )
# Ἰησοῦν Χριστὸν καὶ τοῦτον ἐσταυρωμένον
# Phrase Node: 17525002 ( 1Cor.3.11!12 )
# Ἰησοῦς Χριστός
# Phrase Node: 17607001 ( 1Cor.4.15!12 )
# ἐν Χριστῷ Ἰησοῦ διὰ τοῦ εὐαγγελίου ἐγὼ ὑμᾶς ἐγέννησα
# Phrase Node: 17611003 ( 1Cor.4.17!19 )
# τὰς ὁδούς μου τὰς ἐν Χριστῷ Ἰησοῦ
# Phrase Node: 17694005 ( 1Cor.6.11!10 )
# ἐδικαιώθητε ἐν τῷ ὀνόματι τοῦ Κυρίου Ἰησοῦ Χριστοῦ καὶ ἐν τῷ Πνεύματι τοῦ Θεοῦ ἡμῶν
# Phrase Node: 17893002 ( 1Cor.8.6!16 )
# εἷς Κύριος Ἰησοῦς Χριστός
# Phrase Node: 18609002 ( 1Cor.15.31!11 )
# ἐν Χριστῷ Ἰησοῦ τῷ Κυρίῳ ἡμῶν
# Phrase Node: 18684003 ( 1Cor.15.57!10 )
# διὰ τοῦ Κυρίου ἡμῶν Ἰησοῦ Χριστοῦ
# Phrase Node: 18755002 ( 1Cor.16.24!7 )
# ἐν Χριστῷ Ἰησοῦ
# Phrase Node: 18756000 ( 2Cor.1.1!1 )
# Παῦλος ἀπόστολος Χριστοῦ Ἰησοῦ διὰ θελήματος Θεοῦ καὶ Τιμόθεος ὁ ἀδελφὸς
# Phrase Node: 18759002 ( 2Cor.1.2!5 )
# ἀπὸ Θεοῦ Πατρὸς ἡμῶν καὶ Κυρίου Ἰησοῦ Χριστοῦ
# Phrase Node: 18760000 ( 2Cor.1.3!1 )
# Εὐλογητὸς ὁ Θεὸς καὶ Πατὴρ τοῦ Κυρίου ἡμῶν Ἰησοῦ Χριστοῦ ὁ Πατὴρ τῶν οἰκτιρμῶν καὶ Θεὸς πάσης παρακλήσεως ὁ
# Phrase Node: 18813000 ( 2Cor.1.19!1 )
# ὁ τοῦ Θεοῦ Υἱὸς Χριστὸς Ἰησοῦς ὁ
# Phrase Node: 18944000 ( 2Cor.4.5!6 )
# Χριστὸν Ἰησοῦν Κύριον
# Phrase Node: 19171001 ( 2Cor.8.9!1 )
# γινώσκετε τὴν χάριν τοῦ Κυρίου ἡμῶν Ἰησοῦ Χριστοῦ
# Phrase Node: 19525000 ( 2Cor.13.5!15 )
# Ἰησοῦς Χριστὸς
# Phrase Node: 19551000 ( 2Cor.13.13!1 )
# Ἠ χάρις τοῦ Κυρίου Ἰησοῦ Χριστοῦ καὶ ἡ ἀγάπη τοῦ Θεοῦ καὶ ἡ κοινωνία τοῦ Ἁγίου Πνεύματος
# Phrase Node: 19552000 ( Gal.1.1!1 )
# Παῦλος ἀπόστολος οὐκ ἀπ’ ἀνθρώπων οὐδὲ δι’ ἀνθρώπου ἀλλὰ διὰ Ἰησοῦ Χριστοῦ καὶ Θεοῦ Πατρὸς τοῦ καὶ οἱ σὺν ἐμοὶ πάντες ἀδελφοί
# Phrase Node: 19554002 ( Gal.1.3!5 )
# ἀπὸ Θεοῦ Πατρὸς ἡμῶν καὶ Κυρίου Ἰησοῦ Χριστοῦ τοῦ
# Phrase Node: 19585000 ( Gal.1.12!11 )
# δι’ ἀποκαλύψεως Ἰησοῦ Χριστοῦ
# Phrase Node: 19623002 ( Gal.2.4!14 )
# ἐν Χριστῷ Ἰησοῦ
# Phrase Node: 19665001 ( Gal.2.16!11 )
# μὴ διὰ πίστεως Χριστοῦ Ἰησοῦ
# Phrase Node: 19660002 ( Gal.2.16!16 )
# καὶ ἡμεῖς εἰς Χριστὸν Ἰησοῦν ἐπιστεύσαμεν
# Phrase Node: 19688002 ( Gal.3.1!7 )
# οἷς κατ’ ὀφθαλμοὺς Ἰησοῦς Χριστὸς προεγράφη ἐσταυρωμένος
# Phrase Node: 19725003 ( Gal.3.14!10 )
# ἐν Ἰησοῦ Χριστῷ
# Phrase Node: 19754001 ( Gal.3.22!12 )
# ἐκ πίστεως Ἰησοῦ Χριστοῦ
# Phrase Node: 19763001 ( Gal.3.26!1 )
# Πάντες υἱοὶ Θεοῦ ἐστε διὰ τῆς πίστεως ἐν Χριστῷ Ἰησοῦ
# Phrase Node: 19767001 ( Gal.3.28!16 )
# πάντες ὑμεῖς εἷς ἐστε ἐν Χριστῷ Ἰησοῦ
# Phrase Node: 19809001 ( Gal.4.14!20 )
# Χριστὸν Ἰησοῦν
# Phrase Node: 19867001 ( Gal.5.6!1 )
# ἐν Χριστῷ Ἰησοῦ οὔτε ἀλλὰ
# Phrase Node: 19913001 ( Gal.5.24!1 )
# οἱ τοῦ Χριστοῦ Ἰησοῦ τὴν σάρκα ἐσταύρωσαν σὺν τοῖς παθήμασιν καὶ ταῖς ἐπιθυμίαις
# Phrase Node: 19955001 ( Gal.6.14!8 )
# ἐν τῷ σταυρῷ τοῦ Κυρίου ἡμῶν Ἰησοῦ Χριστοῦ
# Phrase Node: 19960000 ( Gal.6.18!1 )
# Ἠ χάρις τοῦ Κυρίου ἡμῶν Ἰησοῦ Χριστοῦ μετὰ τοῦ πνεύματος ὑμῶν
# Phrase Node: 19961000 ( Eph.1.1!1 )
# Παῦλος ἀπόστολος Χριστοῦ Ἰησοῦ διὰ θελήματος Θεοῦ
# Phrase Node: 19961001 ( Eph.1.1!8 )
# τοῖς ἁγίοις τοῖς καὶ πιστοῖς ἐν Χριστῷ Ἰησοῦ
# Phrase Node: 19963002 ( Eph.1.2!5 )
# ἀπὸ Θεοῦ Πατρὸς ἡμῶν καὶ Κυρίου Ἰησοῦ Χριστοῦ
# Phrase Node: 19964001 ( Eph.1.3!2 )
# ὁ Θεὸς καὶ Πατὴρ τοῦ Κυρίου ἡμῶν Ἰησοῦ Χριστοῦ ὁ
# Phrase Node: 19968003 ( Eph.1.5!5 )
# διὰ Ἰησοῦ Χριστοῦ
# Phrase Node: 19984001 ( Eph.1.17!2 )
# ὁ Θεὸς τοῦ Κυρίου ἡμῶν Ἰησοῦ Χριστοῦ ὁ Πατὴρ τῆς δόξης δώῃ ὑμῖν πνεῦμα σοφίας καὶ ἀποκαλύψεως ἐν ἐπιγνώσει αὐτοῦ
# Phrase Node: 20008002 ( Eph.2.6!4 )
# συνεκάθισεν ἐν τοῖς ἐπουρανίοις ἐν Χριστῷ Ἰησοῦ
# Phrase Node: 20009001 ( Eph.2.7!2 )
# ἐνδείξηται ἐν τοῖς αἰῶσιν τοῖς τὸ ὑπερβάλλον πλοῦτος τῆς χάριτος αὐτοῦ ἐν χρηστότητι ἐφ’ ἡμᾶς ἐν Χριστῷ Ἰησοῦ
# Phrase Node: 20016001 ( Eph.2.10!6 )
# ἐν Χριστῷ Ἰησοῦ
# Phrase Node: 20026001 ( Eph.2.13!1 )
# νυνὶ ἐν Χριστῷ Ἰησοῦ ὑμεῖς οἵ ἐγενήθητε ἐγγὺς ἐν τῷ αἵματι τοῦ Χριστοῦ
# Phrase Node: 20042002 ( Eph.2.20!11 )
# αὐτοῦ Χριστοῦ Ἰησοῦ
# Phrase Node: 20045000 ( Eph.3.1!1 )
# Τούτου χάριν ἐγὼ Παῦλος ὁ δέσμιος τοῦ Χριστοῦ Ἰησοῦ ὑπὲρ ὑμῶν τῶν ἐθνῶν
# Phrase Node: 20053003 ( Eph.3.6!11 )
# ἐν Χριστῷ Ἰησοῦ
# Phrase Node: 20061002 ( Eph.3.11!7 )
# ἐν τῷ Χριστῷ Ἰησοῦ τῷ Κυρίῳ ἡμῶν
# Phrase Node: 20076002 ( Eph.3.21!1 )
# αὐτῷ ἡ δόξα ἐν τῇ ἐκκλησίᾳ καὶ ἐν Χριστῷ Ἰησοῦ εἰς πάσας τὰς γενεὰς τοῦ αἰῶνος τῶν αἰώνων
# Phrase Node: 20199003 ( Eph.5.20!5 )
# ἐν ὀνόματι τοῦ Κυρίου ἡμῶν Ἰησοῦ Χριστοῦ
# Phrase Node: 20285003 ( Eph.6.23!8 )
# ἀπὸ Θεοῦ Πατρὸς καὶ Κυρίου Ἰησοῦ Χριστοῦ
# Phrase Node: 20287001 ( Eph.6.24!7 )
# τὸν Κύριον ἡμῶν Ἰησοῦν Χριστὸν
# Phrase Node: 20288000 ( Phil.1.1!1 )
# Παῦλος καὶ Τιμόθεος δοῦλοι Χριστοῦ Ἰησοῦ
# Phrase Node: 20288001 ( Phil.1.1!7 )
# πᾶσιν τοῖς ἁγίοις ἐν Χριστῷ Ἰησοῦ τοῖς
# Phrase Node: 20290002 ( Phil.1.2!5 )
# ἀπὸ Θεοῦ Πατρὸς ἡμῶν καὶ Κυρίου Ἰησοῦ Χριστοῦ
# Phrase Node: 20294002 ( Phil.1.6!12 )
# ἄχρι ἡμέρας Χριστοῦ Ἰησοῦ
# Phrase Node: 20300002 ( Phil.1.8!10 )
# ἐν σπλάγχνοις Χριστοῦ Ἰησοῦ
# Phrase Node: 20306001 ( Phil.1.11!2 )
# καρπὸν δικαιοσύνης τὸν διὰ Ἰησοῦ Χριστοῦ
# Phrase Node: 20323001 ( Phil.1.19!4 )
# τοῦτό μοι ἀποβήσεται εἰς σωτηρίαν διὰ τῆς ὑμῶν δεήσεως καὶ ἐπιχορηγίας τοῦ Πνεύματος Ἰησοῦ Χριστοῦ κατὰ τὴν ἀποκαραδοκίαν καὶ ἐλπίδα μου
# Phrase Node: 20346001 ( Phil.1.26!2 )
# τὸ καύχημα ὑμῶν περισσεύῃ ἐν Χριστῷ Ἰησοῦ ἐν ἐμοὶ διὰ τῆς ἐμῆς παρουσίας πάλιν πρὸς ὑμᾶς
# Phrase Node: 20371001 ( Phil.2.5!5 )
# ὃ καὶ ἐν Χριστῷ Ἰησοῦ
# Phrase Node: 20383001 ( Phil.2.11!6 )
# ΚΥΡΙΟΣ ΙΗΣΟΥΣ ΧΡΙΣΤΟΣ
# Phrase Node: 20410001 ( Phil.2.21!8 )
# τὰ Χριστοῦ Ἰησοῦ
# Phrase Node: 20443002 ( Phil.3.3!11 )
# καυχώμενοι ἐν Χριστῷ Ἰησοῦ
# Phrase Node: 20452003 ( Phil.3.8!10 )
# διὰ τὸ τῆς γνώσεως Χριστοῦ Ἰησοῦ τοῦ Κυρίου μου
# Phrase Node: 20464003 ( Phil.3.12!17 )
# ὑπὸ Χριστοῦ Ἰησοῦ
# Phrase Node: 20467003 ( Phil.3.14!1 )
# κατὰ σκοπὸν διώκω εἰς τὸ βραβεῖον τῆς ἄνω κλήσεως τοῦ Θεοῦ ἐν Χριστῷ Ἰησοῦ
# Phrase Node: 20485002 ( Phil.3.20!8 )
# ἐξ οὗ καὶ ἀπεκδεχόμεθα Σωτῆρα Κύριον Ἰησοῦν Χριστόν
# Phrase Node: 20500001 ( Phil.4.7!2 )
# ἡ εἰρήνη τοῦ Θεοῦ ἡ φρουρήσει τὰς καρδίας ὑμῶν καὶ τὰ νοήματα ὑμῶν ἐν Χριστῷ Ἰησοῦ
# Phrase Node: 20546001 ( Phil.4.19!1 )
# ὁ Θεός μου πληρώσει πᾶσαν χρείαν ὑμῶν κατὰ τὸ πλοῦτος αὐτοῦ ἐν δόξῃ ἐν Χριστῷ Ἰησοῦ
# Phrase Node: 20548002 ( Phil.4.21!4 )
# ἐν Χριστῷ Ἰησοῦ
# Phrase Node: 20551000 ( Phil.4.23!1 )
# Ἠ χάρις τοῦ Κυρίου Ἰησοῦ Χριστοῦ
# Phrase Node: 20552000 ( Col.1.1!1 )
# Παῦλος ἀπόστολος Χριστοῦ Ἰησοῦ διὰ θελήματος Θεοῦ καὶ Τιμόθεος ὁ ἀδελφὸς
# Phrase Node: 20554000 ( Col.1.3!1 )
# Εὐχαριστοῦμεν τῷ Θεῷ Πατρὶ τοῦ Κυρίου ἡμῶν Ἰησοῦ Χριστοῦ πάντοτε
# Phrase Node: 20556001 ( Col.1.4!2 )
# τὴν πίστιν ὑμῶν ἐν Χριστῷ Ἰησοῦ καὶ τὴν ἀγάπην
# Phrase Node: 20626001 ( Col.2.6!4 )
# τὸν Χριστὸν Ἰησοῦν
# Phrase Node: 20740002 ( Col.4.12!3 )
# Ἐπαφρᾶς ὁ ἐξ ὑμῶν δοῦλος Χριστοῦ Ἰησοῦ
# Phrase Node: 20759001 ( 1Thess.1.1!6 )
# τῇ ἐκκλησίᾳ Θεσσαλονικέων ἐν Θεῷ Πατρὶ καὶ Κυρίῳ Ἰησοῦ Χριστῷ
# Phrase Node: 20763002 ( 1Thess.1.3!2 )
# ὑμῶν τοῦ ἔργου τῆς πίστεως καὶ τοῦ κόπου τῆς ἀγάπης καὶ τῆς ὑπομονῆς τῆς ἐλπίδος τοῦ Κυρίου ἡμῶν Ἰησοῦ Χριστοῦ
# Phrase Node: 20824002 ( 1Thess.2.14!15 )
# ἐν Χριστῷ Ἰησοῦ
# Phrase Node: 20962003 ( 1Thess.5.9!10 )
# εἰς περιποίησιν σωτηρίας διὰ τοῦ Κυρίου ἡμῶν Ἰησοῦ Χριστοῦ τοῦ
# Phrase Node: 20984001 ( 1Thess.5.18!4 )
# τοῦτο θέλημα Θεοῦ ἐν Χριστῷ Ἰησοῦ εἰς ὑμᾶς
# Phrase Node: 20991002 ( 1Thess.5.23!22 )
# ἐν τῇ παρουσίᾳ τοῦ Κυρίου ἡμῶν Ἰησοῦ Χριστοῦ
# Phrase Node: 20998000 ( 1Thess.5.28!1 )
# Ἠ χάρις τοῦ Κυρίου ἡμῶν Ἰησοῦ Χριστοῦ
# Phrase Node: 20999001 ( 2Thess.1.1!6 )
# τῇ ἐκκλησίᾳ Θεσσαλονικέων ἐν Θεῷ Πατρὶ ἡμῶν καὶ Κυρίῳ Ἰησοῦ Χριστῷ
# Phrase Node: 21000002 ( 2Thess.1.2!5 )
# ἀπὸ Θεοῦ Πατρὸς καὶ Κυρίου Ἰησοῦ Χριστοῦ
# Phrase Node:
Κυρίου Ἰησοῦ Χριστοῦ
# Phrase Node: 21703002 ( Phlm.1.9!11 )
# νυνὶ καὶ δέσμιος Χριστοῦ Ἰησοῦ
# Phrase Node: 21733002 ( Phlm.1.23!3 )
# Ἐπαφρᾶς ὁ συναιχμάλωτός μου ἐν Χριστῷ Ἰησοῦ Μᾶρκος Ἀρίσταρχος Δημᾶς Λουκᾶς οἱ συνεργοί μου
# Phrase Node: 21734000 ( Phlm.1.25!1 )
# Ἠ χάρις τοῦ Κυρίου Ἰησοῦ Χριστοῦ
# Phrase Node: 22249002 ( Heb.10.10!6 )
# διὰ τῆς προσφορᾶς τοῦ σώματος Ἰησοῦ Χριστοῦ
# Phrase Node: 22550000 ( Heb.13.8!1 )
# Ἰησοῦς Χριστὸς ἐχθὲς καὶ σήμερον ὁ αὐτός
# Phrase Node: 22590004 ( Heb.13.21!19 )
# διὰ Ἰησοῦ Χριστοῦ
# Phrase Node: 22599000 ( Jas.1.1!1 )
# Ἰάκωβος Θεοῦ καὶ Κυρίου Ἰησοῦ Χριστοῦ δοῦλος
# Phrase Node: 22677001 ( Jas.2.1!3 )
# μὴ ἐν προσωπολημψίαις ἔχετε τὴν πίστιν τοῦ Κυρίου ἡμῶν Ἰησοῦ Χριστοῦ τῆς δόξης
# Phrase Node: 22934000 ( 1Pet.1.1!1 )
# Πέτρος ἀπόστολος Ἰησοῦ Χριστοῦ
# Phrase Node: 22934001 ( 1Pet.1.1!5 )
# ἐκλεκτοῖς παρεπιδήμοις Διασπορᾶς Πόντου Γαλατίας Καππαδοκίας Ἀσίας καὶ Βιθυνίας κατὰ πρόγνωσιν Θεοῦ Πατρός ἐν ἁγιασμῷ Πνεύματος εἰς ὑπακοὴν καὶ ῥαντισμὸν αἵματος Ἰησοῦ Χριστοῦ
# Phrase Node: 22936001 ( 1Pet.1.3!2 )
# ὁ Θεὸς καὶ Πατὴρ τοῦ Κυρίου ἡμῶν Ἰησοῦ Χριστοῦ ὁ
# Phrase Node: 22937004 ( 1Pet.1.3!22 )
# δι’ ἀναστάσεως Ἰησοῦ Χριστοῦ ἐκ νεκρῶν
# Phrase Node: 22942003 ( 1Pet.1.7!22 )
# ἐν ἀποκαλύψει Ἰησοῦ Χριστοῦ
# Phrase Node: 22957001 ( 1Pet.1.13!9 )
# τελείως ἐλπίσατε ἐπὶ τὴν χάριν ἐν ἀποκαλύψει Ἰησοῦ Χριστοῦ
# Phrase Node: 22990006 ( 1Pet.2.5!12 )
# ἀνενέγκαι πνευματικὰς θυσίας εὐπροσδέκτους Θεῷ διὰ Ἰησοῦ Χριστοῦ
# Phrase Node: 23111005 ( 1Pet.3.21!18 )
# δι’ ἀναστάσεως Ἰησοῦ Χριστοῦ
# Phrase Node: 23138003 ( 1Pet.4.11!23 )
# διὰ Ἰησοῦ Χριστοῦ
# Phrase Node: 23197000 ( 2Pet.1.1!1 )
# Συμεὼν Πέτρος δοῦλος καὶ ἀπόστολος Ἰησοῦ Χριστοῦ
# Phrase Node: 23198003 ( 2Pet.1.1!13 )
# ἐν δικαιοσύνῃ τοῦ Θεοῦ ἡμῶν καὶ Σωτῆρος Ἰησοῦ Χριστοῦ
# Phrase Node: 23213001 ( 2Pet.1.8!1 )
# ταῦτα οὐκ ἀργοὺς οὐδὲ ἀκάρπους καθίστησιν εἰς τὴν τοῦ Κυρίου ἡμῶν Ἰησοῦ Χριστοῦ ἐπίγνωσιν
# Phrase Node: 23222001 ( 2Pet.1.11!1 )
# οὕτως πλουσίως ἐπιχορηγηθήσεται ὑμῖν ἡ εἴσοδος εἰς τὴν αἰώνιον βασιλείαν τοῦ Κυρίου ἡμῶν καὶ Σωτῆρος Ἰησοῦ Χριστοῦ
# Phrase Node: 23231001 ( 2Pet.1.14!11 )
# καὶ ὁ Κύριος ἡμῶν Ἰησοῦς Χριστὸς ἐδήλωσέν μοι
# Phrase Node: 23235003 ( 2Pet.1.16!8 )
# τὴν τοῦ Κυρίου ἡμῶν Ἰησοῦ Χριστοῦ δύναμιν καὶ παρουσίαν
# Phrase Node: 23306002 ( 2Pet.2.20!8 )
# ἐν ἐπιγνώσει τοῦ Κυρίου καὶ Σωτῆρος Ἰησοῦ Χριστοῦ
# Phrase Node: 23356001 ( 2Pet.3.18!1 )
# αὐξάνετε ἐν χάριτι καὶ γνώσει τοῦ Κυρίου ἡμῶν καὶ Σωτῆρος Ἰησοῦ Χριστοῦ
# Phrase Node: 23372001 ( 1John.1.3!15 )
# καὶ ἡ κοινωνία ἡ ἡμετέρα μετὰ τοῦ Πατρὸς καὶ μετὰ τοῦ Υἱοῦ αὐτοῦ Ἰησοῦ Χριστοῦ
# Phrase Node: 23403002 ( 1John.2.1!14 )
# ἔχομεν πρὸς τὸν Πατέρα Παράκλητον Ἰησοῦν Χριστὸν δίκαιον
# Phrase Node: 23486001 ( 1John.2.22!10 )
# Ἰησοῦς οὐκ ἔστιν ὁ Χριστός
# Phrase Node: 23607000 ( 1John.3.23!8 )
# πιστεύσωμεν τῷ ὀνόματι τοῦ Υἱοῦ αὐτοῦ Ἰησοῦ Χριστοῦ
# Phrase Node: 23623002 ( 1John.4.2!12 )
# Ἰησοῦν Χριστὸν ἐν σαρκὶ ἐληλυθότα
# Phrase Node: 23703001 ( 1John.5.1!5 )
# Ἰησοῦς ἐστιν ὁ Χριστὸς
# Phrase Node: 23722001 ( 1John.5.6!9 )
# Ἰησοῦς Χριστός
# Phrase Node: 23781001 ( 1John.5.20!18 )
# ἐσμὲν ἐν τῷ ἀληθινῷ ἐν τῷ Υἱῷ αὐτοῦ Ἰησοῦ Χριστῷ
# Phrase Node: 23788002 ( 2John.1.3!4 )
# χάρις ἔλεος εἰρήνη παρὰ Θεοῦ Πατρός καὶ παρὰ Ἰησοῦ Χριστοῦ τοῦ Υἱοῦ τοῦ Πατρός
# Phrase Node: 23804002 ( 2John.1.7!11 )
# Ἰησοῦν Χριστὸν ἐρχόμενον ἐν σαρκί
# Phrase Node: 23878000 ( Jude.1.1!1 )
# Ἰούδας Ἰησοῦ Χριστοῦ δοῦλος δὲ ἀδελφὸς Ἰακώβου
# Phrase Node: 23879002 ( Jude.1.1!14 )
# Ἰησοῦ Χριστῷ τετηρημένοις
# Phrase Node: 23888002 ( Jude.1.4!22 )
# τὸν μόνον Δεσπότην καὶ Κύριον ἡμῶν Ἰησοῦν Χριστὸν ἀρνούμενοι
# Phrase Node: 23929001 ( Jude.1.17!9 )
# ὑπὸ τῶν ἀποστόλων τοῦ Κυρίου ἡμῶν Ἰησοῦ Χριστοῦ
# Phrase Node: 23937001 ( Jude.1.21!7 )
# τὸ ἔλεος τοῦ Κυρίου ἡμῶν Ἰησοῦ Χριστοῦ
# Phrase Node: 23943001 ( Jude.1.24!1 )
# Τῷ μόνῳ Θεῷ Σωτῆρι ἡμῶν διὰ Ἰησοῦ Χριστοῦ τοῦ Κυρίου ἡμῶν δόξα μεγαλωσύνη κράτος καὶ ἐξουσία πρὸ παντὸς τοῦ αἰῶνος καὶ νῦν καὶ εἰς πάντας τοὺς αἰῶνας
# Phrase Node: 23947000 ( Rev.1.1!1 )
# Ἀποκάλυψις Ἰησοῦ Χριστοῦ
# Phrase Node: 23953002 ( Rev.1.2!3 )
# τὸν λόγον τοῦ Θεοῦ καὶ τὴν μαρτυρίαν Ἰησοῦ Χριστοῦ
# Phrase Node: 23961002 ( Rev.1.4!13 )
# ἀπὸ ὁ καὶ ὁ καὶ ὁ καὶ ἀπὸ τῶν ἑπτὰ Πνευμάτων καὶ ἀπὸ Ἰησοῦ Χριστοῦ ὁ μάρτυς ὁ πιστός ὁ πρωτότοκος τῶν νεκρῶν καὶ ὁ ἄρχων τῶν βασιλέων τῆς γῆς

# %%
# Finally, let's try a sentence search:
words_by_sentence_node = {}
for w in gnt:
    s = w["sentence_node"]
    if s not in words_by_sentence_node:
        words_by_sentence_node[s] = []
    words_by_sentence_node[s].append(w)

# %%
first_word = list(filter(lambda w: w["lemma"]=="αἷμα", gnt))
matching_sentences = []
for w in first_word:
    s = w["sentence_node"]
    ws = words_by_sentence_node[s]
    matches = list(filter(lambda w: w["lemma"]=="βασιλεία", ws))
    if len(matches) > 0:
        matching_sentences.append(s)

print("RESULTS:", len(matching_sentences))
for s in matching_sentences:
    print("Sentence Node:", s, "(", words_by_sentence_node[s][0]["wid"], ")")
    print_ws(words_by_sentence_node[s])
# Out:
# RESULTS: 3
# Sentence Node: 5889 ( 1Cor.15.50!1 )
# Τοῦτο φημι ἀδελφοί ὅτι σὰρξ καὶ αἷμα βασιλείαν Θεοῦ οὐ δύναται ἡ φθορὰ τὴν ἀφθαρσίαν κληρονομεῖ
# Sentence Node: 7549 ( Rev.1.5!20 )
# Τῷ ἀγαπῶντι ἡμᾶς λύσαντι ἡμᾶς ἐκ τῶν ἁμαρτιῶν ἡμῶν ἐν τῷ αἵματι αὐτοῦ καὶ βασιλείαν ἱερεῖς τῷ Θεῷ καὶ Πατρὶ αὐτοῦ αὐτῷ ἡ δόξα καὶ τὸ κράτος εἰς τοὺς αἰῶνας τῶν αἰώνων ἀμήν
# Sentence Node: 7653 ( Rev.5.9!2 )
# ᾄδουσιν ᾠδὴν καινὴν λέγοντες Ἄξιος εἶ λαβεῖν τὸ βιβλίον ἀνοῖξαι τὰς σφραγῖδας αὐτοῦ ὅτι ἐσφάγης ἠγόρασας τῷ Θεῷ ἐν τῷ αἵματί σου ἐκ πάσης φυλῆς καὶ γλώσσης καὶ λαοῦ καὶ ἔθνους ἐποίησας αὐτοὺς τῷ Θεῷ ἡμῶν βασιλείαν καὶ ἱερεῖς βασιλεύσουσιν ἐπὶ τῆς γῆς
